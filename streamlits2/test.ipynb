# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os

# %%
garret_burhenn_pitches_csv = Path("datasets\daces.csv").parents[1] / 'datasets\daces.csv'

# %%
asd=pd.read_csv(garret_burhenn_pitches_csv)

# %%
asd.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
races=pd.read_csv("datasets\daces.csv")
circuits=pd.read_csv("datasets\circuits.csv")
constructor=pd.read_csv("datasets\constructor.csv")
drivers=pd.read_csv("datasets\drivers.csv")
pitstop=pd.read_csv("datasets\pitstop.csv")
result=pd.read_csv("datasets\desult.csv",encoding="latin-1")

# %%
constructor.head()

# %%
rc=races.drop(columns=["name","round","time","date","url","name","circuitId"],axis=1)

# %%
rc.head()
# Out:
#    raceId  year
# 0       1  2009
# 1       2  2009
# 2       3  2009
# 3       4  2009
# 4       5  2009

# %%
races.value_counts("year").head(1)
# Out:
# year
# 2021    23
# dtype: int64

# %%
result.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452           218.3         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
re=result.drop(columns=["resultId","raceId","constructorId","number","grid","positionText","positionOrder","points","laps","time","milliseconds","fastestLap","rank","fastestLapTime","fastestLapSpeed","statusId"],axis=1)

# %%
re.drop(columns="Total",inplace=True)

# %%
re.dropna(inplace=True)

# %%
re.dtypes
# Out:
# driverId      int64
# position     object
# Total       float64
# dtype: object

# %%
(re.driverId).dropna(inplace=True)

# %%
re.tail(
)
# Out:
#        driverId position  Total
# 24955       841       16    NaN
# 24956       849       17    NaN
# 24957       825       18    NaN
# 24958       850       19    NaN
# 24959       815       \N    NaN

# %%
re["Total"]=re.groupby("driverId").size()

# %%
from operator import index


result[result["position"]=="1"].value_counts("driverId").head(1)
# Out:
# driverId
# 1    95
# dtype: int64

# %%
drivers[drivers["driverId"]==1]
# Out:
#    driverId driverRef number code name/forename name/surname         dob  \
# 0         1  hamilton     44  HAM         Lewis     Hamilton  1985-01-07
#
#   nationality                                          url
# 0     British  http://en.wikipedia.org/wiki/Lewis_Hamilton

# %% [markdown]
# CIRCUITO

# %%
races.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
races.value_counts("name").head(1)
# Out:
# name
# Italian Grand Prix    72
# dtype: int64

# %%
races.name.count()
# Out:
# 1058

# %%
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt  \
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park

# %% [markdown]
# PILOTO

# %%
result.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452           218.3         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
result[result["position"]=="1"].value_counts("driverId").head()

# %%
constructor.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
#JOIN DE 2 DATASETS
resul_total=pd.merge(result,drivers ,on="driverId")

# %%
result_constructor_total=pd.merge(resul_total,constructor,on="constructorId")

# %%
result_constructor_total.head()
# Out:
#    resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         1      18         1              1       22     1        1
# 1        27      19         1              1       22     9        5
# 2        57      20         1              1       22     3       13
# 3        69      21         1              1       22     5        3
# 4        90      22         1              1       22     3        2
#
#   positionText  positionOrder  points  ...  code name/forename name/surname  \
# 0            1              1    10.0  ...   HAM         Lewis     Hamilton
# 1            5              5     4.0  ...   HAM         Lewis     Hamilton
# 2           13             13     0.0  ...   HAM         Lewis     Hamilton
# 3            3              3     6.0  ...   HAM         Lewis     Hamilton
# 4            2              2     8.0  ...   HAM         Lewis     Hamilton
#
#           dob nationality_x                                        url_x  \
# 0  1985-01-07       British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1  1985-01-07       British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2  1985-01-07       British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3  1985-01-07       British  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4  1985-01-07       British  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
#   constructorRef     name nationality_y                                 url_y
# 0        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 1        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 2        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 3        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
# 4        mclaren  McLaren       British  http://en.wikipedia.org/wiki/McLaren
#
# [5 rows x 30 columns]

# %% [markdown]
# CONSTRUCTOR

# %%
#SOLO AMERICAN
CA=result_constructor_total[result_constructor_total["nationality_x"]=="American"]
#SOLO BRITISH
CB=result_constructor_total[result_constructor_total["nationality_x"]=="British"]

# %%
#Resultado general constructor con mas puntos
result_constructor_total["constructorRef"].value_counts("points")

# %%
#Resultado cosntructor con mas puntos(AMERICAN)
CA["constructorRef"].value_counts("points")

# %%
#Resultado constructor con mas puntos(BRITISH)
CB["constructorRef"].value_counts("points")

# %% [markdown]
# PILOTO

# %%
#SOLO AMERICAN
RA=resul_total[resul_total["nationality"]=="American"]

# %%
#SOLO BRITISH
RB=resul_total[resul_total["nationality"]=="British"]

# %%
#Resultado general piloto con mas puntos
resul_total["driverRef"].value_counts("points")

# %%
#Resultado piloto con mas puntos(AMERICAN)
RA["driverRef"].value_counts("points")

# %%
#Resultado piloto con mas puntos(BRITISH)
RB["driverRef"].value_counts("points")

# %%
retotal["nationality"],retotal["points"],retotal["driverRef"]
# Out:
# (0          British
#  1          British
#  2          British
#  3          British
#  4          British
#             ...
#  24955     Canadian
#  24956     Canadian
#  24957      British
#  24958    Brazilian
#  24959    Brazilian
#  Name: nationality, Length: 24960, dtype: object,
#  0        10.0
#  1         4.0
#  2         0.0
#  3         6.0
#  4         8.0
#           ...
#  24955     0.0
#  24956     0.0
#  24957     0.0
#  24958     0.0
#  24959     0.0
#  Name: points, Length: 24960, dtype: float64,
#  0                 hamilton
#  1                 hamilton
#  2                 hamilton
#  3                 hamilton
#  4                 hamilton
#                 ...
#  24955               latifi
#  24956               latifi
#  24957               aitken
#  24958    pietro_fittipaldi
#  24959    pietro_fittipaldi
#  Name: driverRef, Length: 24960, dtype: object)

# %%
resul_British["driverRef"].value_counts("points")
# Out:
# raikkonen             0.013301
# barrichello           0.013061
# alonso                0.012580
# button                0.012380
# michael_schumacher    0.012340
#                         ...
# jimmy_stewart         0.000040
# ian_stewart           0.000040
# mayer                 0.000040
# schroeder             0.000040
# bassi                 0.000040
# Name: driverRef, Length: 850, dtype: float64

# %%
RB=resul_British[resul_British["nationality"]=="British"].groupby("points").head().count()

# %%
RB
# Out:
# resultId           88
# raceId             88
# driverId           88
# constructorId      88
# number_x           88
# grid               88
# position           88
# positionText       88
# positionOrder      88
# points             88
# laps               88
# time               88
# milliseconds       88
# fastestLap         88
# rank               88
# fastestLapTime     88
# fastestLapSpeed    88
# statusId           88
# driverRef          88
# number_y           88
# code               88
# name/forename      88
# name/surname       88
# dob                88
# nationality        88
# url                88
# dtype: int64

# %%
retotal.head()
# Out:
#    resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         1      18         1              1       22     1        1
# 1        27      19         1              1       22     9        5
# 2        57      20         1              1       22     3       13
# 3        69      21         1              1       22     5        3
# 4        90      22         1              1       22     3        2
#
#   positionText  positionOrder  points  ...  fastestLapSpeed statusId  \
# 0            1              1    10.0  ...            218.3        1
# 1            5              5     4.0  ...          209.033        1
# 2           13             13     0.0  ...          203.969       11
# 3            3              3     6.0  ...          204.323        1
# 4            2              2     8.0  ...          222.085        1
#
#   driverRef number_y code name/forename name/surname         dob nationality  \
# 0  hamilton       44  HAM         Lewis     Hamilton  1985-01-07     British
# 1  hamilton       44  HAM         Lewis     Hamilton  1985-01-07     British
# 2  hamilton       44  HAM         Lewis     Hamilton  1985-01-07     British
# 3  hamilton       44  HAM         Lewis     Hamilton  1985-01-07     British
# 4  hamilton       44  HAM         Lewis     Hamilton  1985-01-07     British
#
#                                            url
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
# [5 rows x 26 columns]
